# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedabrar786/Qr-code-generator-/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Weather Data visualization objective

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df['Date'] = pd.date_range(start='2000-01-01', periods=len(df), freq='D')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.to_period('M')

# %% [markdown]
# # 1. Line Chart: Temperature trends over time (monthly average)

# %%
monthly_temp = df.groupby('Month')[['MinTemp', 'MaxTemp']].mean()

plt.figure(figsize=(12, 6))
monthly_temp['MinTemp'].plot(label='Min Temp')
monthly_temp['MaxTemp'].plot(label='Max Temp')
plt.title('Monthly Temperature Trends')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Bar Graph: Total rainfall per year

# %%
yearly_rainfall = df.groupby('Year')['Rainfall'].sum()

plt.figure(figsize=(12, 6))
yearly_rainfall.plot(kind='bar', color='skyblue')
plt.title('Total Rainfall Per Year')
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Scatter Plot: Temperature vs. Humidity

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Temp3pm'], y=df['Humidity3pm'])
plt.title('Temperature vs Humidity (3pm)')
plt.xlabel('Temperature at 3pm (°C)')
plt.ylabel('Humidity at 3pm (%)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Linear Regression Forecast: Predict future MaxTemp trends
# # Average yearly max temperature

# %%
yearly_avg_temp = df.groupby('Year')['MaxTemp'].mean().dropna().reset_index()

# %% [markdown]
# # Prepare data for regression

# %%
X = yearly_avg_temp['Year'].values.reshape(-1, 1)
y = yearly_avg_temp['MaxTemp'].values
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict for next 10 years

# %%
future_years = np.arange(X[-1][0] + 1, X[-1][0] + 11).reshape(-1, 1)
future_preds = model.predict(future_years)

# %% [markdown]
# # Plot

# %%
# Plot
plt.figure(figsize=(12, 6))
plt.plot(X, y, 'bo-', label='Historical Avg MaxTemp')
plt.plot(future_years, future_preds, 'r--', label='Forecasted MaxTemp')
plt.title('Max Temperature Trend Forecast')
plt.xlabel('Year')
plt.ylabel('Max Temperature (°C)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #conclusion
#
#
#
# The visualizations effectively highlight key climate patterns and relationships within the dataset. The line chart showcased how temperature fluctuates over time, helping identify seasonal or yearly trends. The bar graph offered a clear comparison of total rainfall across different years, revealing patterns in precipitation. Through the scatter plot, we observed the relationship between temperature and humidity, offering insights into atmospheric conditions. Finally, the trend line and forecasting model provided a predictive view of future temperature trends using linear regression, aiding in climate planning and analysis. Together, these visual tools enhance understanding and support informed decision-making in weather and climate monitoring.
